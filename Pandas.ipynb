# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/refs/heads/master/BostonHousing.csv")

# %%
# df.to_csv("D:\sujal class\files\Bosten_data.csv")

# %%
d={"key":"value","age":"21"}

# %%
d['age']
# Out:
# '21'

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df['crim']
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: crim, Length: 506, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
df['age'].dtype
# Out:
# dtype('float64')

# %%
df['crim'].dtype
# Out:
# dtype('float64')

# %%
df=pd.read_excel(r"D:\sujal class\files\Titanic.xlsx")

# %%
df[['Age','Name']]
# Out:
#       Age                                               Name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# ..    ...                                                ...
# 886  27.0                              Montvila, Rev. Juozas
# 887  19.0                       Graham, Miss. Margaret Edith
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0                              Behr, Mr. Karl Howell
# 890  32.0                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
type(df[['Age','Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %%
# To check the object value in the table.

df.dtypes=="object"
# Out:
# PassengerId    False
# Name            True
# Pclass         False
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# Survived       False
# dtype: bool

# %%
# By this it only give object values.

df.dtypes[df.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
# for proper way

df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
#  it give only that column in which object is present

df[df.dtypes[df.dtypes=="object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes=="object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df[df.dtypes[df.dtypes=="float"].index].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df1=pd.read_csv(r"D:\sujal class\files\car_data.csv")

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# Slicing operation
# row wise
df1[1:7]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
#
#   Seller_Type Transmission  Owner
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0
# 6      Dealer       Manual      0

# %%
df1[1:6:2]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner
# 1      Dealer       Manual      0
# 3      Dealer       Manual      0
# 5      Dealer       Manual      0

# %%
# Column wise

df1['Car_Name'][1:7]
# Out:
# 1              sx4
# 2             ciaz
# 3          wagon r
# 4            swift
# 5    vitara brezza
# 6             ciaz
# Name: Car_Name, dtype: object

# %%
df1=pd.read_csv(r"D:\sujal class\files\car_data.csv")

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# Adding new colomn in the table
#  If colunm name already exist then it upaate the value.

df1["Current_Year"]=2025

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year
# 0        Dealer       Manual      0          2025
# ...

# %%
df1['Difference']=df1['Current_Year']-df1['Year']

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year  Difference
# ...

# %%
#  Is null

df.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
#  To find the maximum driven km in the table.

df1[df1['Kms_Driven'] == max(df1['Kms_Driven'])]
# Out:
#       Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 196  Activa 3g  2008           0.17           0.52      500000    Petrol
#
#     Seller_Type Transmission  Owner  Current_Year  Difference
# 196  Individual    Automatic      0          2025          17

# %%
# For a specific column

df1[df1['Kms_Driven'] == max(df1['Kms_Driven'])]['Year']
# Out:
# 196    2008
# Name: Year, dtype: int64

# %%
#  To check the cars are from years 2014.

df1[df1['Year']==2014]
# Out:
#                  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0                    ritz  2014           3.35          5.590       27000
# 4                   swift  2014           4.60          6.870       42450
# 23               alto k10  2014           2.50          3.460       45280
# 32                  swift  2014           4.95          7.490       39000
# 33                 ertiga  2014           6.00          9.950       45000
# 34                  dzire  2014           5.50          8.060       45000
# 41               alto k10  2014           2.55          3.980       46706
# 43                  dzire  2014           5.50          8.060       45780
# 45                   ciaz  2014           7.50         12.040       15000
# 58                etios g  2014           4.10          6.800       39485
# 59               fortuner  2014          19.99         35.960       41000
# 62               fortuner  2014          18.75         35.960       78000
# ...

# %%
df1[df1['Year']==2014].shape
# Out:
# (38, 11)

# %%
len(df1[df1['Year']==2014])
# Out:
# 38

# %%
#  car is greater than 2014 and kms driven is less than 7000 if both condition will be true

df1[(df1['Year']>2014) & (df1['Kms_Driven']<7000)]
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 2                         ciaz  2017           7.25           9.85
# 5                vitara brezza  2018           9.25           9.83
# 10                    alto 800  2017           2.85           3.60
# 21                       ignis  2017           4.90           5.71
# 64                    fortuner  2017          33.00          36.23
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# 103          Bajaj Dominar 400  2017           1.45           1.60
# 104  Royal Enfield Classic 350  2017           1.35           1.47
# 110                  KTM RC200  2016           1.20           1.78
# 120         Bajaj Pulsar RS200  2016           1.05           1.26
# 122   Royal Enfield Bullet 350  2016           1.05           1.17
# ...

# %%
df2=pd.read_csv(r"D:\sujal class\files\daily_total_births.csv")

# %%
df2
# Out:
#            Date  Births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %%
df2.head()
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
df2.shape
# Out:
# (365, 2)

# %%
df2.isnull().sum()
# Out:
# Date      0
# Births    0
# dtype: int64

# %%
df2.describe()
# Out:
#            Births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    object
#  1   Births  365 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
date = pd.to_datetime(df2['Date'])

# %%
date
# Out:
# 0     1959-01-01
# 1     1959-01-02
# 2     1959-01-03
# 3     1959-01-04
# 4     1959-01-05
#          ...
# 360   1959-12-27
# 361   1959-12-28
# 362   1959-12-29
# 363   1959-12-30
# 364   1959-12-31
# Name: Date, Length: 365, dtype: datetime64[ns]

# %%
# To add new column in the table

df2['converted_date']=pd.to_datetime(df2['Date'])

# %%
df2
# Out:
#            Date  Births converted_date
# 0    1959-01-01      35     1959-01-01
# 1    1959-01-02      32     1959-01-02
# 2    1959-01-03      30     1959-01-03
# 3    1959-01-04      31     1959-01-04
# 4    1959-01-05      44     1959-01-05
# ..          ...     ...            ...
# 360  1959-12-27      37     1959-12-27
# 361  1959-12-28      52     1959-12-28
# 362  1959-12-29      48     1959-12-29
# 363  1959-12-30      55     1959-12-30
# 364  1959-12-31      50     1959-12-31
#
# [365 rows x 3 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            365 non-null    object
#  1   Births          365 non-null    int64
#  2   converted_date  365 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
# To acces the year
df2['Year']=df2['converted_date'].dt.year

# %%
df2.head()
# Out:
#          Date  Births converted_date  Year
# 0  1959-01-01      35     1959-01-01  1959
# 1  1959-01-02      32     1959-01-02  1959
# 2  1959-01-03      30     1959-01-03  1959
# 3  1959-01-04      31     1959-01-04  1959
# 4  1959-01-05      44     1959-01-05  1959

# %%
df2.tail()
# Out:
#            Date  Births converted_date  Year
# 360  1959-12-27      37     1959-12-27  1959
# 361  1959-12-28      52     1959-12-28  1959
# 362  1959-12-29      48     1959-12-29  1959
# 363  1959-12-30      55     1959-12-30  1959
# 364  1959-12-31      50     1959-12-31  1959

# %%
df2['Month']=df2['converted_date'].dt.month

# %%
df2
# Out:
#            Date  Births converted_date  Year  Month
# 0    1959-01-01      35     1959-01-01  1959      1
# 1    1959-01-02      32     1959-01-02  1959      1
# 2    1959-01-03      30     1959-01-03  1959      1
# 3    1959-01-04      31     1959-01-04  1959      1
# 4    1959-01-05      44     1959-01-05  1959      1
# ..          ...     ...            ...   ...    ...
# 360  1959-12-27      37     1959-12-27  1959     12
# 361  1959-12-28      52     1959-12-28  1959     12
# 362  1959-12-29      48     1959-12-29  1959     12
# 363  1959-12-30      55     1959-12-30  1959     12
# 364  1959-12-31      50     1959-12-31  1959     12
#
# [365 rows x 5 columns]

# %%
df2['week']=df2['converted_date'].dt.isocalendar().week

# %%
df2
# Out:
#            Date  Births converted_date  Year  Month  week
# 0    1959-01-01      35     1959-01-01  1959      1     1
# 1    1959-01-02      32     1959-01-02  1959      1     1
# 2    1959-01-03      30     1959-01-03  1959      1     1
# 3    1959-01-04      31     1959-01-04  1959      1     1
# 4    1959-01-05      44     1959-01-05  1959      1     2
# ..          ...     ...            ...   ...    ...   ...
# 360  1959-12-27      37     1959-12-27  1959     12    52
# 361  1959-12-28      52     1959-12-28  1959     12    53
# 362  1959-12-29      48     1959-12-29  1959     12    53
# 363  1959-12-30      55     1959-12-30  1959     12    53
# 364  1959-12-31      50     1959-12-31  1959     12    53
#
# [365 rows x 6 columns]

# %%
df2['Month'].value_counts()
# Out:
# 1     31
# 3     31
# 5     31
# 7     31
# 8     31
# 10    31
# 12    31
# 4     30
# 6     30
# 9     30
# 11    30
# 2     28
# Name: Month, dtype: int64

# %%
df2.head()
# Out:
#          Date  Births converted_date  Year  Month  week
# 0  1959-01-01      35     1959-01-01  1959      1     1
# 1  1959-01-02      32     1959-01-02  1959      1     1
# 2  1959-01-03      30     1959-01-03  1959      1     1
# 3  1959-01-04      31     1959-01-04  1959      1     1
# 4  1959-01-05      44     1959-01-05  1959      1     2

# %%
# Drop = is used for remove column

df2.drop('week',axis=1)
# Out:
#            Date  Births converted_date  Year  Month
# 0    1959-01-01      35     1959-01-01  1959      1
# 1    1959-01-02      32     1959-01-02  1959      1
# 2    1959-01-03      30     1959-01-03  1959      1
# 3    1959-01-04      31     1959-01-04  1959      1
# 4    1959-01-05      44     1959-01-05  1959      1
# ..          ...     ...            ...   ...    ...
# 360  1959-12-27      37     1959-12-27  1959     12
# 361  1959-12-28      52     1959-12-28  1959     12
# 362  1959-12-29      48     1959-12-29  1959     12
# 363  1959-12-30      55     1959-12-30  1959     12
# 364  1959-12-31      50     1959-12-31  1959     12
#
# [365 rows x 5 columns]

# %%
# inplace save the data in same dataframe

df2.drop('week',axis=1,inplace=True)

# %%
df2
# Out:
#            Date  Births converted_date  Year  Month
# 0    1959-01-01      35     1959-01-01  1959      1
# 1    1959-01-02      32     1959-01-02  1959      1
# 2    1959-01-03      30     1959-01-03  1959      1
# 3    1959-01-04      31     1959-01-04  1959      1
# 4    1959-01-05      44     1959-01-05  1959      1
# ..          ...     ...            ...   ...    ...
# 360  1959-12-27      37     1959-12-27  1959     12
# 361  1959-12-28      52     1959-12-28  1959     12
# 362  1959-12-29      48     1959-12-29  1959     12
# 363  1959-12-30      55     1959-12-30  1959     12
# 364  1959-12-31      50     1959-12-31  1959     12
#
# [365 rows x 5 columns]

# %%
# Remove row wise

df2.drop(1)
# Out:
#            Date  Births converted_date  Year  Month
# 0    1959-01-01      35     1959-01-01  1959      1
# 2    1959-01-03      30     1959-01-03  1959      1
# 3    1959-01-04      31     1959-01-04  1959      1
# 4    1959-01-05      44     1959-01-05  1959      1
# 5    1959-01-06      29     1959-01-06  1959      1
# ..          ...     ...            ...   ...    ...
# 360  1959-12-27      37     1959-12-27  1959     12
# 361  1959-12-28      52     1959-12-28  1959     12
# 362  1959-12-29      48     1959-12-29  1959     12
# 363  1959-12-30      55     1959-12-30  1959     12
# 364  1959-12-31      50     1959-12-31  1959     12
#
# [364 rows x 5 columns]

# %%
# Loc[] give data index wise

df2.loc[2]
# Out:
# Date                       1959-01-03
# Births                             30
# converted_date    1959-01-03 00:00:00
# Year                             1959
# Month                               1
# Name: 2, dtype: object

# %%
df2.loc[[2,3]]
# Out:
#          Date  Births converted_date  Year  Month
# 2  1959-01-03      30     1959-01-03  1959      1
# 3  1959-01-04      31     1959-01-04  1959      1

# %%
df2.loc[2:7]
# Out:
#          Date  Births converted_date  Year  Month
# 2  1959-01-03      30     1959-01-03  1959      1
# 3  1959-01-04      31     1959-01-04  1959      1
# 4  1959-01-05      44     1959-01-05  1959      1
# 5  1959-01-06      29     1959-01-06  1959      1
# 6  1959-01-07      45     1959-01-07  1959      1
# 7  1959-01-08      43     1959-01-08  1959      1

# %%
df2.loc[2:7:2]
# Out:
#          Date  Births converted_date  Year  Month
# 2  1959-01-03      30     1959-01-03  1959      1
# 4  1959-01-05      44     1959-01-05  1959      1
# 6  1959-01-07      45     1959-01-07  1959      1

# %%
df2.loc[2:7,['Date','Births','converted_date']]
# Out:
#          Date  Births converted_date
# 2  1959-01-03      30     1959-01-03
# 3  1959-01-04      31     1959-01-04
# 4  1959-01-05      44     1959-01-05
# 5  1959-01-06      29     1959-01-06
# 6  1959-01-07      45     1959-01-07
# 7  1959-01-08      43     1959-01-08

# %%
# iloc 

df2.iloc[2:7, 0:3]
# Out:
#          Date  Births converted_date
# 2  1959-01-03      30     1959-01-03
# 3  1959-01-04      31     1959-01-04
# 4  1959-01-05      44     1959-01-05
# 5  1959-01-06      29     1959-01-06
# 6  1959-01-07      45     1959-01-07

# %%
df.dropna()
# Out:
#      PassengerId                                               Name  Pclass  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 6              7                            McCarthy, Mr. Timothy J       1
# 10            11                    Sandstrom, Miss. Marguerite Rut       3
# 11            12                           Bonnell, Miss. Elizabeth       1
# ..           ...                                                ...     ...
# 871          872   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)       1
# 872          873                           Carlsson, Mr. Frans Olof       1
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)       1
# 887          888                       Graham, Miss. Margaret Edith       1
# 889          890                              Behr, Mr. Karl Howell       1
#
# ...

# %%
df.dropna(thresh=3)
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
# fillna mean add value on the place of null value

df.fillna(4)
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
data={
    'name':['abc','def','ghi','hij'],
    'salary':[100,200,300,400],
    'mail_id':['abc@gmail.com','def@gmail.com','ghi@gmail.com','hij@gmail.com'],
    'addr':['mum','pune','delhi','mum']
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   name  salary        mail_id   addr
# 0  abc     100  abc@gmail.com    mum
# 1  def     200  def@gmail.com   pune
# 2  ghi     300  ghi@gmail.com  delhi
# 3  hij     400  hij@gmail.com    mum

# %%
pd.DataFrame(data )
# Out:
#   name  salary        mail_id   addr
# 0  abc     100  abc@gmail.com    mum
# 1  def     200  def@gmail.com   pune
# 2  ghi     300  ghi@gmail.com  delhi
# 3  hij     400  hij@gmail.com    mum

# %%
data1={
    'pf_num' : [234,456,234,567],
    'income_tax' : [4545,655,342,3234],
    'mobile_num' : [23243,123342,34534,23423],
    'course' : ['DS','DA','PFS','FS']
}

# %%
df1=pd.DataFrame(data1)

# %%
df1
# Out:
#    pf_num  income_tax  mobile_num course
# 0     234        4545       23243     DS
# 1     456         655      123342     DA
# 2     234         342       34534    PFS
# 3     567        3234       23423     FS

# %%
# concat

pd.concat([df,df1],axis=1)
# Out:
#   name  salary        mail_id   addr  pf_num  income_tax  mobile_num course
# 0  abc     100  abc@gmail.com    mum     234        4545       23243     DS
# 1  def     200  def@gmail.com   pune     456         655      123342     DA
# 2  ghi     300  ghi@gmail.com  delhi     234         342       34534    PFS
# 3  hij     400  hij@gmail.com    mum     567        3234       23423     FS

# %%
data2={
    '0' : ['abc','bcd','efg','hij'],
    '1' : [100,200,300,400],
    '2' : ['abc@gmail.com','def@gmail.com','ghi@gmail.com','hij@gmail.com'],
    '3' : ['Mumbai','Pune','Mumbai','Banglore']
}

data3 = {
    '0' : [234,45,54465,656],
    '1' : [234,565,300,400],
    '2' : [23453,45678,45546,434546],
    '3' : ['ds','bigdata','python','web']
}

# %%
df2=pd.DataFrame(data2)
df3=pd.DataFrame(data3,index=[4,5,6,7])

# %%
df2
# Out:
#      0    1              2         3
# 0  abc  100  abc@gmail.com    Mumbai
# 1  bcd  200  def@gmail.com      Pune
# 2  efg  300  ghi@gmail.com    Mumbai
# 3  hij  400  hij@gmail.com  Banglore

# %%
df3
# Out:
#        0    1       2        3
# 4    234  234   23453       ds
# 5     45  565   45678  bigdata
# 6  54465  300   45546   python
# 7    656  400  434546      web

# %%
pd.concat([df2,df3])
# Out:
#        0    1              2         3
# 0    abc  100  abc@gmail.com    Mumbai
# 1    bcd  200  def@gmail.com      Pune
# 2    efg  300  ghi@gmail.com    Mumbai
# 3    hij  400  hij@gmail.com  Banglore
# 4    234  234          23453        ds
# 5     45  565          45678   bigdata
# 6  54465  300          45546    python
# 7    656  400         434546       web

# %%
data4={
    'emp_id' : [101,102,103,104],
    'salary' : [234,345,200,400],
    'pf' : [23,34,56,78]
}

data5={
    'emp_id' : [101,102,103,104],
    'mobile_no' : [3434,5656,767,678],
    'house_no' : [345,345,345,345]
}

# %%
df4=pd.DataFrame(data4)
df5=pd.DataFrame(data5)

# %%
df4
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
df5
# Out:
#    emp_id  mobile_no  house_no
# 0     101       3434       345
# 1     102       5656       345
# 2     103        767       345
# 3     104        678       345

# %%
#  Merge

pd.merge(df4,df5)
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     234  23       3434       345
# 1     102     345  34       5656       345
# 2     103     200  56        767       345
# 3     104     400  78        678       345

# %%
pd.merge(df4,df5,how='left')
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     234  23       3434       345
# 1     102     345  34       5656       345
# 2     103     200  56        767       345
# 3     104     400  78        678       345

# %%
pd.merge(df4,df5 , how = 'left' , on = 'emp_id')
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     234  23       3434       345
# 1     102     345  34       5656       345
# 2     103     200  56        767       345
# 3     104     400  78        678       345

# %%
data6={
    'emp_id1' : [101,102,103,104],
    'salary1' : [234,345,200,400],
    'pf1' : [23,34,56,78]
}

data7={
    'emp_id2' : [101,102,103,104],
    'mobile_no2' : [3434,5656,767,678],
    'house_no2' : [345,345,345,345]
}

# %%
df6=pd.DataFrame(data6)
df7=pd.DataFrame(data7)

# %%
df6
# Out:
#    emp_id1  salary1  pf1
# 0      101      234   23
# 1      102      345   34
# 2      103      200   56
# 3      104      400   78

# %%
df7
# Out:
#    emp_id2  mobile_no2  house_no2
# 0      101        3434        345
# 1      102        5656        345
# 2      103         767        345
# 3      104         678        345

# %%
pd.merge(df6,df7, left_on='emp_id1',right_on='emp_id2')
# Out:
#    emp_id1  salary1  pf1  emp_id2  mobile_no2  house_no2
# 0      101      234   23      101        3434        345
# 1      102      345   34      102        5656        345
# 2      103      200   56      103         767        345
# 3      104      400   78      104         678        345

# %%
data8={
    'emp_id' : [101,102,103,104],
    'salary' : [234,345,200,400],
    'pf' : [23,34,56,78]
}

data9={
    'emp_id' : [101,102,104,105,123],
    'mobile_no' : [3434,5656,767,678,454],
    'house_no' : [345,345,345,345,4534]
}

# %%
df8=pd.DataFrame(data8)
df9=pd.DataFrame(data9)

# %%
df8
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
df9
# Out:
#    emp_id  mobile_no  house_no
# 0     101       3434       345
# 1     102       5656       345
# 2     104        767       345
# 3     105        678       345
# 4     123        454      4534

# %%
pd.merge(df8,df9)
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     234  23       3434       345
# 1     102     345  34       5656       345
# 2     104     400  78        767       345

# %%
data10={
    'emp_id1' : [101,102,103,104],
    'salary1' : [234,345,200,400],
    'pf1' : [23,34,56,78]
}

data11={
    'emp_id2' : [101,102,104,105,123],
    'mobile_no2' : [3434,5656,767,678,454],
    'house_no2' : [345,345,345,345,4534]
}

# %%
df10=pd.DataFrame(data10 , index=['a','b','c','d'])
df11=pd.DataFrame(data11 , index=['a','b','d','e','f'])

# %%
df10
# Out:
#    emp_id1  salary1  pf1
# a      101      234   23
# b      102      345   34
# c      103      200   56
# d      104      400   78

# %%
df11
# Out:
#    emp_id2  mobile_no2  house_no2
# a      101        3434        345
# b      102        5656        345
# d      104         767        345
# e      105         678        345
# f      123         454       4534

# %%
df10.join(df11)
# Out:
#    emp_id1  salary1  pf1  emp_id2  mobile_no2  house_no2
# a      101      234   23    101.0      3434.0      345.0
# b      102      345   34    102.0      5656.0      345.0
# c      103      200   56      NaN         NaN        NaN
# d      104      400   78    104.0       767.0      345.0

# %%
df11.join(df10)
# Out:
#    emp_id2  mobile_no2  house_no2  emp_id1  salary1   pf1
# a      101        3434        345    101.0    234.0  23.0
# b      102        5656        345    102.0    345.0  34.0
# d      104         767        345    104.0    400.0  78.0
# e      105         678        345      NaN      NaN   NaN
# f      123         454       4534      NaN      NaN   NaN

# %%
df=pd.read_csv(r"D:\sujal class\files\car_data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# If present price is greater than 5 print high less than 5 print low

def review(x):
    if x>5:
        return("high")
    else:
        return("low")

# %%
df['Review']=df['Present_Price'].apply(review)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner Review
# 0      Dealer       Manual      0   high
# 1      Dealer       Manual      0   high
# 2      Dealer       Manual      0   high
# 3      Dealer       Manual      0    low
# 4      Dealer       Manual      0   high

# %%
#  To check the length of car name column

df['Car_length']=df['Car_Name'].apply(len)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner Review  Car_length
# 0      Dealer       Manual      0   high           4
# 1      Dealer       Manual      0   high           3
# 2      Dealer       Manual      0   high           4
# 3      Dealer       Manual      0    low           7
# 4      Dealer       Manual      0   high           5

# %%
df=pd.read_excel(r"D:\sujal class\files\Titanic.xlsx")

# %%
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
# To check category

pd.Categorical(df)
# Out:
# ['PassengerId', 'Name', 'Pclass', 'Sex', 'Age', ..., 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived']
# Length: 12
# Categories (12, object): ['Age', 'Cabin', 'Embarked', 'Fare', ..., 'Sex', 'SibSp', 'Survived', 'Ticket']

# %%
# To check the category in specific column

pd.Categorical(df['Embarked'])
# Out:
# ['S', 'C', 'S', 'S', 'S', ..., 'S', 'S', 'S', 'C', 'Q']
# Length: 891
# Categories (3, object): ['C', 'Q', 'S']

# %%
pd.Categorical(df['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
# To check unique value from table 

df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
a= ["abc" , "der" , "hello" , "good"]

# %%
df1=pd.Series(a)

# %%
df1
# Out:
# 0      abc
# 1      der
# 2    hello
# 3     good
# dtype: object

# %%
df=pd.read_csv(r"D:\sujal class\files\car_data.csv")

# %%
df.duplicated().sum()
# Out:
# 2

# %%
# check the duplacated value with the row
df[df.duplicated()==True]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Seller_Type Transmission  Owner
# 17      Dealer       Manual      0
# 93      Dealer    Automatic      0

# %%
#  to delate duplacate values

df.drop_duplicates()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# To change value in the column

df['Year'].replace(2014,2025,inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2025           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2025           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
#  convert data frame into array

array = df.to_numpy()

# %%
array
# Out:
# array([['ritz', 2025, 3.35, ..., 'Dealer', 'Manual', 0],
#        ['sx4', 2013, 4.75, ..., 'Dealer', 'Manual', 0],
#        ['ciaz', 2017, 7.25, ..., 'Dealer', 'Manual', 0],
#        ...,
#        ['city', 2009, 3.35, ..., 'Dealer', 'Manual', 0],
#        ['city', 2017, 11.5, ..., 'Dealer', 'Manual', 0],
#        ['brio', 2016, 5.3, ..., 'Dealer', 'Manual', 0]], dtype=object)

# %%
type(array)
# Out:
# numpy.ndarray

# %%
array.ndim
# Out:
# 2

# %%
pd.DataFrame(array)
# Out:
#            0     1     2     3      4       5       6       7  8
# 0       ritz  2025  3.35  5.59  27000  Petrol  Dealer  Manual  0
# 1        sx4  2013  4.75  9.54  43000  Diesel  Dealer  Manual  0
# 2       ciaz  2017  7.25  9.85   6900  Petrol  Dealer  Manual  0
# 3    wagon r  2011  2.85  4.15   5200  Petrol  Dealer  Manual  0
# 4      swift  2025   4.6  6.87  42450  Diesel  Dealer  Manual  0
# ..       ...   ...   ...   ...    ...     ...     ...     ... ..
# 296     city  2016   9.5  11.6  33988  Diesel  Dealer  Manual  0
# 297     brio  2015   4.0   5.9  60000  Petrol  Dealer  Manual  0
# 298     city  2009  3.35  11.0  87934  Petrol  Dealer  Manual  0
# 299     city  2017  11.5  12.5   9000  Diesel  Dealer  Manual  0
# 300     brio  2016   5.3   5.9   5464  Petrol  Dealer  Manual  0
#
# [301 rows x 9 columns]

# %%
df3=pd.read_csv(r"D:\sujal class\files\admission_data.csv")

# %%
df3.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance_of_ Admit
# 0               0.92
# 1               0.76
# 2               0.72
# 3               0.80
# 4               0.65

# %%
df3.tail()
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance_of_ Admit
# 495               0.87
# 496               0.96
# 497               0.93
# 498               0.73
# 499               0.84

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3.shape
# Out:
# (500, 8)

# %%
df3.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance_of_ Admit
# count  500.000000  500.000000          500.00000
# mean     8.576440    0.560000            0.72174
# std      0.604813    0.496884            0.14114
# min      6.800000    0.000000            0.34000
# 25%      8.127500    0.000000            0.63000
# ...

# %%
df3[1:7]
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
# 5        330          115                  5  4.5   3.0  9.34         1
# 6        321          109                  3  3.0   4.0  8.20         1
#
#    Chance_of_ Admit
# 1               0.76
# 2               0.72
# 3               0.80
# 4               0.65
# 5               0.90
# 6               0.75

# %%
df3[1:7:2]
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 1        324          107                  4  4.0   4.5  8.87         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 5        330          115                  5  4.5   3.0  9.34         1
#
#    Chance_of_ Admit
# 1               0.76
# 3               0.80
# 5               0.90

# %%
df3['GRE Score'][1:8]
# Out:
# 1    324
# 2    316
# 3    322
# 4    314
# 5    330
# 6    321
# 7    308
# Name: GRE Score, dtype: int64

# %%
df3.drop(1)
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# 5          330          115                  5  4.5   3.0  9.34         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance_of_ Admit
# 0                 0.92
# 2                 0.72
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3 = 1

# %%
df3 = df1 + df2

# %%
df3 = pd.DataFrame({...})

# %%
df3
# Out:
#           0
# 0  Ellipsis

# %%
df3.drop(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 df3.drop(1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
# ...

# %%
df3.drop(1, inplace=True)
